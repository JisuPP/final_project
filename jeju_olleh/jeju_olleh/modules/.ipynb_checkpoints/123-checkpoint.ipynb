# %%
import datetime, json, os, requests, pickle
import pandas as pd
import numpy as np
from datetime import datetime
from konlpy.tag import Okt
from django.conf import settings
from sklearn.metrics.pairwise import cosine_similarity
from math import radians, sin, cos, sqrt, atan2

# %%
# 피클 파일을 읽어올 경로와 파일명 설정
file_path = r'C:\Users\gherwt\Desktop\파이널 프로젝트\data1\tfidf_matrix.pkl'

# 피클 파일 읽어오기
with open(file_path, 'rb') as f:
    tfidf_matrix = pickle.load(f)
# 읽어온 데이터를 사용하여 원하는 작업 수행

# %%
# 피클 파일을 읽어올 경로와 파일명 설정
file_path = r'C:\Users\gherwt\Desktop\파이널 프로젝트\data1\tfidf_vectorizer.pkl'

# 피클 파일 읽어오기
with open(file_path, 'rb') as f:
    tfidf_vectorizer = pickle.load(f)
# 읽어온 데이터를 사용하여 원하는 작업 수행

# %%
def get_address_info(address):

    # 주소를 가져오기 위한 url
    apiurl = "https://api.vworld.kr/req/address?"

    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": address,
        "format": "json",
        "type": "road",
        "key": "054C4365-485B-35C4-9219-1C30E6B61D7C"
    }
    response = requests.get(apiurl, params=params)

    if response.status_code == 200:

        data = response.json()

        if 'response' in data and 'refined' in data['response'] and 'text' in data['response']['refined']:
            address = data['response']['refined']['text']
            latitude = float(data['response']['result']['point']['y'])
            longitude = float(data['response']['result']['point']['x'])
            
            # DataFrame 생성
            df = pd.DataFrame({
                'Address': [address],
                'Latitude': [latitude],
                'Longitude': [longitude]
            })

            return df
        
        else:
            print("Failed to retrieve data from the API.")
            return pd.DataFrame()  # 빈 DataFrame 반환
    else:
        print("Failed to retrieve data from the API.")
        return pd.DataFrame()  # 빈 DataFrame 반환

# %%
# 두 지점 간의 Haversine 거리를 계산합니다. 
def lat_long_distance(lat1, lon1, lat2, lon2):
    
    # 지구의 반지름 (단위: km)
    R = 6371.0

    # 라디안으로 변환
    lat1 = np.radians(lat1)  # 여기서 np.radians 사용
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)
    
    # 위도와 경도의 차이 계산
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    # Haversine 공식 계산
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    # 거리 계산
    distance = R * c
    
    return distance

# %%
def tokenize_user_input(user_input):
    okt = Okt()
    # 불용어 설정
    stopwords = pd.read_csv(r'C:\Users\gherwt\Desktop\파이널 프로젝트\data1\ko-stopwords.csv')
    stopwords = list(stopwords['stopwords'])
    stopwords += [
        '에서', '고', '이다', '는', '한', '씨', '것', '거', '게', '데', '이다', '건', '고', '되다', '되어다', '걸', '기',
        '시', '네', '듯', '랍니', '중이', '얘', '스', '도도', '나', '수', '개', '내', '기', '제', '저', '인', '있다', '이렇다',
        '그렇다', '번', '위', '팅', '분', '인', '링', '란', '포', '두', '진짜', '하다', '이다', '가다', '이제', '들다',
        '너무', '먹다', '제주', '제주도', '있다', '있으며', '경우', '대부분', '조황', '로서', '조황', '있는', '최근', '그대로', '해당', '만큼', '등',
        '있게', '있으므로', '더군다나', '다시', '그', '발생', '가장', '중', '아니다', '위해',
        '후', '곳', '주로', '위해', '많다', '매일', '주로', '때문', '곳', '좋다', '좋은',
        '총', '속', '주', '후', '만', '원', '외', '등', '현재', '매장', '없다', '층', '숍', '별로', '리', '흠뻑', '의하다', '점', '도', '이러하다',
        '있는', '있었다', '비짓', '출처', '중요한', '중요하다', '특별자치도', '제주특별자치도'
    ]
    stopwords = set(stopwords)
    pos_words = okt.pos(user_input, stem=True, norm=True)

    # 형태소 분석 및 불용어 제거
    tokens = [word for word, tag in pos_words if tag in ['Noun', 'Adjective'] and word not in stopwords]
    return tokens

# %%
user_input = '아이와 가기 좋은 캠핑장'
user_address = '제주특별자치도 제주시 우도면 우도로 324-1'

# %%
keyword_input = tokenize_user_input(user_input)
keyword_input = ' '.join(keyword_input)
print(keyword_input)
# Out:
# 가기 캠핑장

# %%
user_coordinates = get_address_info(user_address)
user_latitude = user_coordinates['Latitude'].iloc[0]
user_longitude = user_coordinates['Longitude'].iloc[0]
print(user_coordinates)
print(user_latitude)
print(user_longitude)
# Out:
#                      Address  Latitude   Longitude
# 0  제주특별자치도 제주시 우도면 우도로 324-1  33.52027  126.949372
# 33.520269824
# 126.949371607

# %%
df = pd.read_csv(r'C:\Users\gherwt\Desktop\파이널 프로젝트\data1\fin_token.csv')
df.head(5)
# Out:
#    Unnamed: 0         title  \
# 0           0  가시리국산화풍력발전단지
# 1           1   갈중이(천연염색체험)
# 2           2         감귤박물관
# 3           3         감사공묘역
# 4           4       감수굴 밭담길
#
#                                           firstimage cat1   cat2       cat3  \
# 0  http://tong.visitkorea.or.kr/cms/resource/95/3...  A02  A0204  A02040400
# 1  https://blog.kakaocdn.net/dn/Hh733/btrcA1znbC9...  A02  A0203  A02030200
# 2  http://tong.visitkorea.or.kr/cms/resource/68/2...  A02  A0206  A02060100
# 3  http://tong.visitkorea.or.kr/cms/resource/96/3...  A02  A0201  A02010700
# 4  http://tong.visitkorea.or.kr/cms/resource/82/3...  A02  A0203  A02030100
#
#                               addr1        mapx       mapy  \
# 0       제주특별자치도 서귀포시 표선면 녹산로 464-78  126.734110  33.393937
# 1  제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이  126.313658  33.235142
# 2            제주특별자치도 서귀포시 효돈순환로 441  126.608090  33.271182
# 3           제주특별자치도 제주시 조천읍 함대로 362  126.661147  33.512995
# 4           제주특별자치도 제주시 구좌읍 평대7길 34  126.843281  33.531057
#
#                                             overview  Rating  Reviews  \
# 0  제주도 서귀포시 동남쪽 끝에 위치한 표선면 가시리는 제주도 내에서 아직 개발되지 않...     4.7      (3)
# 1  갈옷은 제주도에서 구하기 쉬운 감을 이용해 만든 옷을 말하며 제주에서 일상복으로 즐...     4.6      (7)
# 2  서귀포 감귤 박물관은 제주 특산물인 감귤을 테마로 감귤의 세계를 한눈에 보고, 느끼...     4.0  (1,475)
# 3  조천읍 함덕리에 있는 감사공묘역은 조선 초기 한림학사와 전라감사를 역임한 영암 강영...     5.0      (6)
# 4  평대리 중동에 위치한 감수굴 밭담길은 고즈넉한 마을의 옛 정취 그대로의 풍경을 즐기...     4.5      (2)
#
#                                        overview_prep  \
# 0  제주도 서귀포시 동남쪽 끝에 위치한 표선면 가시리는 제주도 내에서 아직 개발되지 않...
# 1  갈옷은 제주도에서 구하기 쉬운 감을 이용해 만든 옷을 말하며 제주에서 일상복으로 즐...
# 2  서귀포 감귤 박물관은 제주 특산물인 감귤을 테마로 감귤의 세계를 한눈에 보고 느끼고...
# 3  조천읍 함덕리에 있는 감사공묘역은 조선 초기 한림학사와 전라감사를 역임한 영암 강영...
# 4  평대리 중동에 위치한 감수굴 밭담길은 고즈넉한 마을의 옛 정취 그대로의 풍경을 즐기...
#
#                                           tokenizing
# 0  서귀포시 동남쪽 끝 위치 표선면 가시리 개발 지역 년 국내 최초 지역 주민 참여 방...
# 1  갈옷 구 쉽다 감 이용 옷 말 상복 전통 의상 갈옷 자외선 차단 효과 통 기성 뛰어...
# 2  서귀포 감귤 박물관 특산 물 감귤 테마 감귤 세계 한눈 보고 체험 개관 공립 전문 ...
# 3  조천읍 함덕 감사 묘역 조선 초기 한림 학사 전라 감사 역임 영암 강영 선생 묘역 ...
# 4  평 대리 중동 위치 감수 굴 밭 넉 마을 정취 풍경 산책 길이 평 대리 중동 마을 ...

# %%
keyword_input_mat = tfidf_vectorizer.transform([(keyword_input)])
keyword_input_sim = cosine_similarity(keyword_input_mat, tfidf_matrix)
keyword_input_ind = keyword_input_sim.argsort()[:, ::-1]
result_df = df.iloc[keyword_input_ind[0]]
print(keyword_input_ind)
print(result_df)
# Out:
# [[1874 1938 1877 ... 1300 1301    0]]
#       Unnamed: 0         title  \
# 1874        2144        에어그라운드
# 1938        2211  햇살정원 제주캠핑&민박
# 1877        2147        에코힐글램핑
# 1875        2145       에코그린캠핑장
# 1867        2137       숲속야영장휴림
# ...          ...           ...
# 1298        1416           가파도
# 1299        1417        각시바우오름
# 1300        1421           강정천
# 1301        1422          강정포구
# 0              0  가시리국산화풍력발전단지
#
#                                              firstimage cat1   cat2  \
# 1874  http://tong.visitkorea.or.kr/cms/resource/71/2...  A03  A0302
# 1938  http://tong.visitkorea.or.kr/cms/resource/52/2...  A03  A0302
# 1877  http://tong.visitkorea.or.kr/cms/resource/97/2...  A03  A0302
# 1875  http://tong.visitkorea.or.kr/cms/resource/32/2...  A03  A0302
# 1867  http://tong.visitkorea.or.kr/cms/resource/65/2...  A03  A0302
# ...                                                 ...  ...    ...
# 1298  https://blog.kakaocdn.net/dn/Hh733/btrcA1znbC9...  A01  A0101
# 1299  https://blog.kakaocdn.net/dn/Hh733/btrcA1znbC9...  A01  A0101
# 1300  http://tong.visitkorea.or.kr/cms/resource/96/3...  A01  A0101
# 1301  http://tong.visitkorea.or.kr/cms/resource/33/2...  A01  A0101
# 0     http://tong.visitkorea.or.kr/cms/resource/95/3...  A02  A0204
#
#            cat3                        addr1        mapx       mapy  \
# 1874  A03021700   제주특별자치도 서귀포시 남원읍 남태해안로 439  126.746545  33.282058
# 1938  A03021700      제주특별자치도 서귀포시 보목포로65번길 6  126.608208  33.240510
# 1877  A03021700    제주특별자치도 제주시 애월읍 광령평화8길 22  126.440854  33.449926
# 1875  A03021700   제주특별자치도 제주시 애월읍 중산간서로 5587  126.333535  33.444275
# 1867  A03021700     제주특별자치도 제주시 애월읍 광령남서길 40  126.428805  33.443829
# ...         ...                          ...         ...        ...
# 1298  A01011300         제주특별자치도 서귀포시 대정읍 가파로  126.273588  33.166433
# 1299  A01010400        제주특별자치도 서귀포시 호근동 2112  126.526945  33.276780
# 1300  A01010900             제주특별자치도 서귀포시 강정동  126.474738  33.256662
# 1301  A01011400         제주특별자치도 서귀포시 말질로 291  126.475020  33.227162
# 0     A02040400  제주특별자치도 서귀포시 표선면 녹산로 464-78  126.734110  33.393937
#
#                                                overview  Rating Reviews  \
# 1874  에어그라운드 캠핑장은 서귀포 남원읍 태흥포구 옆에 있는 카라반 캠핑장이다. 이곳 카...     4.1    (25)
# 1938  햇살정원 제주캠핑은 서귀포시 보목동에 위치하고 있다. 보목동은 조용하고 아름다운 바...     4.2    (36)
# 1877  제주시 애월읍에 자리하고 있는 에코힐글램핑은 제주공항에서 10분 거리에 있는 럭셔리...     4.5    (29)
# 1875  에코그린캠핑장은 제주특별자치도 제주시 애월읍에 위치하고 있다. 제주공항 20km, ...     4.3    (35)
# 1867  숲속야영장 휴림은 제주시 산림조합에서 운영하는 글램핑, 카라반, 숲속 야영장을 갖추...     4.7    (26)
# ...                                                 ...     ...     ...
# 1298  제주도 부속섬 중 4번째로 큰 섬 가파도는 위에서 내려다보면, 바다를 헤엄쳐 가는 ...     4.6    (69)
# 1299  해발 395m의 기생화산으로 분화구의 형태는 원추형이다. 오름 정상에 있는 각시바위...     4.1     (7)
# 1300  강정천은 물이 많아 이름이  물 강(江) 물 정(汀)인 서귀포시 최남단 마을 강정마...     4.3   (135)
# 1301  해외 휴양지 못지않게 아름다운 자연을 가진 제주도, 그중에서도 서귀포 남쪽 해안을 ...     4.6    (16)
# 0     제주도 서귀포시 동남쪽 끝에 위치한 표선면 가시리는 제주도 내에서 아직 개발되지 않...     4.7     (3)
#
#                                           overview_prep  \
# 1874  에어그라운드 캠핑장은 서귀포 남원읍 태흥포구 옆에 있는 카라반 캠핑장이다 이곳 카라...
# 1938  햇살정원 제주캠핑은 서귀포시 보목동에 위치하고 있다 보목동은 조용하고 아름다운 바닷...
# 1877  제주시 애월읍에 자리하고 있는 에코힐글램핑은 제주공항에서 분 거리에 있는 럭셔리한 ...
# 1875  에코그린캠핑장은 제주특별자치도 제주시 애월읍에 위치하고 있다 제주공항  제주항  제...
# 1867  숲속야영장 휴림은 제주시 산림조합에서 운영하는 글램핑 카라반 숲속 야영장을 갖추고 ...
# ...                                                 ...
# 1298  제주도 부속섬 중 번째로 큰 섬 가파도는 위에서 내려다보면 바다를 헤엄쳐 가는 가오...
# 1299  해발 의 기생화산으로 분화구의 형태는 원추형이다 오름 정상에 있는 각시바위의 이름을...
# 1300  강정천은 물이 많아 이름이  물 강 물 정인 서귀포시 최남단 마을 강정마을 동쪽에 ...
# 1301  해외 휴양지 못지않게 아름다운 자연을 가진 제주도 그중에서도 서귀포 남쪽 해안을 바...
# 0     제주도 서귀포시 동남쪽 끝에 위치한 표선면 가시리는 제주도 내에서 아직 개발되지 않...
#
#                                              tokenizing
# 1874  에어 라운드 캠핑장 서귀포 남원읍 태흥 포구 옆 카라반 캠핑장 카라반 둥글다 모양 ...
# 1938  햇살 정원 캠핑 서귀포시 보목동 위치 보목동 조용하다 아름답다 바닷가 마을 올레 코...
# 1877  제주시 애월읍 자리 에코 힐 글램핑 공항 거리 럭셔리 글램핑 무료 와이파이 사용 여...
# 1875  에코 그린 캠핑장 제주시 애월읍 위치 공항 항 시내 거리 캠핑 최적화 캠핑장 넓다 ...
# 1867  숲속 야영장 림 제주시 산림조합 운영 글램핑 카라반 숲속 야영장 자연휴양림 캠핑장 ...
# ...                                                 ...
# 1298  부속 섬 섬 가파도 바다 헤엄 가오리 모양 이름 가오리 파리 가파도 설 덮개 모양 ...
# 1299  해발 의 기생화산 분화구 형태 원추 오름 정상 바위 이름 시바 오름 불리 한자 악 ...
# 1300  강정 물이 이름 물 강 물 정인 서귀포시 최 남단 마을 강정 마을 동쪽 위치 길이 ...
# 1301  해외 휴양지 못지않다 아름답다 자연 서귀포 남쪽 해안 강정포구 광 멋지다 해군 기지...
# 0     서귀포시 동남쪽 끝 위치 표선면 가시리 개발 지역 년 국내 최초 지역 주민 참여 방...
#
# [1970 rows x 14 columns]

# %%
filtered_df = result_df[result_df.apply(lambda x: lat_long_distance(x['mapy'], x['mapx'], user_latitude, user_longitude) <= 15, axis=1)]
print(filtered_df)
# Out:
#       Unnamed: 0    title                                         firstimage  \
# 1176        1289     평대스낵  http://tong.visitkorea.or.kr/cms/resource/71/2...
# 609          702    목화휴게소  http://tong.visitkorea.or.kr/cms/resource/93/2...
# 627          720    미엘드세화  http://tong.visitkorea.or.kr/cms/resource/55/2...
# 656          752   백기해녀의집  http://tong.visitkorea.or.kr/cms/resource/07/1...
# 632          725  바다는안보여요  http://tong.visitkorea.or.kr/cms/resource/97/1...
# ...          ...      ...                                                ...
# 1216        1330    항아리조림  http://tong.visitkorea.or.kr/cms/resource/11/2...
# 1218        1332   해녀의 부엌  https://blog.kakaocdn.net/dn/Hh733/btrcA1znbC9...
# 1228        1342       해왓  http://tong.visitkorea.or.kr/cms/resource/58/2...
# 1309        1431    검멀레해변  http://tong.visitkorea.or.kr/cms/resource/12/1...
# 1316        1439    광치기해변  http://tong.visitkorea.or.kr/cms/resource/55/2...
#
#      cat1   cat2       cat3                        addr1        mapx  \
# 1176  A05  A0502  A05020100           제주특별자치도 제주시 대수길 26  126.837976
# 609   A05  A0502  A05020100     제주특별자치도 서귀포시 해맞이해안로 2526  126.901694
# 627   A05  A0502  A05020900      제주특별자치도 제주시 해맞이해안로 1464  126.861854
# 656   A05  A0502  A05020100   제주특별자치도 서귀포시 성산읍 일출로 88-19  126.922392
# 632   A05  A0502  A05020900   제주특별자치도 제주시 구좌읍 종달로5길 31-1  126.899449
# ...   ...    ...        ...                          ...         ...
# 1216  A05  A0502  A05020100          제주특별자치도 제주시 세화3길 32  126.856410
# 1218  A05  A0502  A05020100  제주특별자치도 제주시 구좌읍 해맞이해안로 2265  126.912306
# 1228  A05  A0502  A05020100    제주특별자치도 서귀포시 성산읍 신고로 30-1  126.917210
# 1309  A01  A0101  A01011200        제주특별자치도 제주시 우도면 우도해안길  126.968551
# 1316  A01  A0101  A01011200         제주특별자치도 서귀포시 성산읍 고성리  126.923948
#
#            mapy                                           overview  Rating  \
# 1176  33.536640  평대스낵은 제주 평대리 해안가에 있다. 실내는 빈티지하며 작은 공간이지만, 옥상 테...     3.9
# 609   33.481811  목화휴게소는 성산에서 세화방면 올레1코스 바닷가에 있는 편의점이다. 몇 해 전 텔레...     4.0
# 627   33.524550  미엘드세화는 제주특별자치도 제주시 구좌읍 세화리에 있는 디저트 카페다. 세화 항구와...     4.2
# 656   33.449942  백기해녀의집은 광치기해변 인근에 있는 해산물을 전문으로 하는 음식점이다. 섭지코지에...     4.1
# 632   33.493323  [제주시 구좌읍 종달리에 위치한 카페 바다는안보여요]<br />\n바다는안보여요 카...     4.2
# ...         ...                                                ...     ...
# 1216  33.526199  항아리조림은 제주시 세화민속오일시장 근처에 있다. 갈치전문점으로 대표메뉴인 갈치조림...     4.5
# 1218  33.497817  버려진 해녀의 공간을 재생, 해녀들이 직접 채취한 해산물을 활용한 로컬 푸드 다이닝...     4.7
# 1228  33.438524  해왓은 바다를 연상케 하는 시원한 블루칼라 외관 덕분에 멀리서도 눈에 띄는 식당이다...     4.4
# 1309  33.496730  검멀레 해수욕장은 제주도 동쪽 끝 성산포에서 북동쪽 해상에 위치한 화산섬 우도에 있...     4.3
# 1316  33.452309  성산일출봉에서 섭지코지로 향하는 길목에 있는 광치기 해변은 제주올레 1코스의 마지막...     4.4
#
#       Reviews                                      overview_prep  \
# 1176    (388)  평대스낵은 제주 평대리 해안가에 있다 실내는 빈티지하며 작은 공간이지만 옥상 테이블...
# 609     (524)  목화휴게소는 성산에서 세화방면 올레코스 바닷가에 있는 편의점이다 몇 해 전 텔레비전...
# 627     (214)  미엘드세화는 제주특별자치도 제주시 구좌읍 세화리에 있는 디저트 카페다 세화 항구와 ...
# 656     (489)  백기해녀의집은 광치기해변 인근에 있는 해산물을 전문으로 하는 음식점이다 섭지코지에서...
# 632     (101)  제주시 구좌읍 종달리에 위치한 카페 바다는안보여요 바다는안보여요 카페는 이름처럼 바...
# ...       ...                                                ...
# 1216     (96)  항아리조림은 제주시 세화민속오일시장 근처에 있다 갈치전문점으로 대표메뉴인 갈치조림의...
# 1218    (204)  버려진 해녀의 공간을 재생 해녀들이 직접 채취한 해산물을 활용한 로컬 푸드 다이닝과...
# 1228    (805)  해왓은 바다를 연상케 하는 시원한 블루칼라 외관 덕분에 멀리서도 눈에 띄는 식당이다...
# 1309  (4,008)  검멀레 해수욕장은 제주도 동쪽 끝 성산포에서 북동쪽 해상에 위치한 화산섬 우도에 있...
# 1316    (639)  성산일출봉에서 섭지코지로 향하는 길목에 있는 광치기 해변은 제주올레 코스의 마지막이...
#
#                                              tokenizing
# 1176  평 스낵 평 대리 해안가 실내 빈티 지하 작다 공간 옥상 테이블 바다 음식 오션 뷰...
# 609   목화 휴게소 성산 화방 올레 코스 바닷가 편의점 몇 해 전 텔레비전 예능 프로그램 ...
# 627   밉다 화 제주시 구좌읍 화리 디저트 카페 화 항구 화 해수욕장 앞 바다 뷰 대표 메...
# 656   해녀 광 치기 해변 인근 해산물 전문 음식점 섭지코지 성산일출봉 길가 위치 성게 해...
# 632   제주시 구좌읍 종 달리 위치 카페 바다 안보 여요 바다 안보 여요 카페 이름 바다 ...
# ...                                                 ...
# 1216  항아리 조림 제주시 화 민속 시장 근처 갈치 전문점 대표 메뉴인 갈치 조림 은 갈치...
# 1218  버려진 해녀 공간 재생 해녀 직접 채취 해산물 활용 로컬 푸드 다이닝 해녀 삶 공연...
# 1228  해왓 바다 연상 케 시원하다 블루 칼라 외관 덕분 멀리 서도 눈 식당 넓다 주차장 ...
# 1309  검멀레 해수욕장 동쪽 끝 성산포 북동쪽 해상 위치 화산섬 우도 유명하다 해수욕장 우...
# 1316  성산일출봉 섭지코지 향 길목 광 치기 해변 올레 코스 마지막 이자 코스 시작 용암 ...
#
# [209 rows x 14 columns]

# %%
def rec_address(request):
    if request.method == 'POST':

        # 사용자가 입력한 정보 가져오기
        user_input = user_input
        user_address = user_address
        keyword_input = tokenize_user_input(user_input)
        keyword_input = ' '.join(keyword_input)

        # 주소
        user_coordinates = get_address_info(user_address)
        user_latitude = user_coordinates['Latitude'].iloc[0]
        user_longitude = user_coordinates['Longitude'].iloc[0]

        # 데이터 가져오기
        file_path = os.path.join(settings.BASE_DIR, 'jeju_olleh', 'modules', 'fin_token.csv')
        df = pd.read_csv(file_path, encoding='utf-8')

        # TF-IDF matrix, vectorizer 가져오기
        tfidf_mat = load_tfidf_matrix()
        tfidf_vect = load_tfidf_vectorizer()

        # 사용자 입력 키워드에 대한 TF-IDF 값 계산
        keyword_input_mat = tfidf_vect.transform([(keyword_input)])
        keyword_input_sim = cosine_similarity(keyword_input_mat, tfidf_mat)
        keyword_input_ind = keyword_input_sim.argsort()[:, ::-1]
        
        result_df = df.iloc[keyword_input_ind[0]]

        # result_df['selected_image_url'] = result_df['title'].apply(get_image_url)

        filtered_df = result_df[result_df.apply(lambda x: lat_long_distance(x['mapx'], x['mapy'], user_latitude, user_longitude) <= 15, axis=1)]

        recommended_places = filtered_df.head(5)

        return render(request, 'rec_app/other.html', {'user_longitude': user_longitude, 'user_latitude': user_latitude })
    return render(request, 'rec_app/rec_input.html')
